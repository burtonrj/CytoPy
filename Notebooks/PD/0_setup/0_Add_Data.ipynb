# %%
import sys
if '/home/ross/immunova' not in sys.path:
    sys.path.append('/home/ross/immunova')
from immunova.data.patient import Patient, Bug, Biology, Drug
from immunova.data.fcs_experiments import FCSExperiment
from immunova.data.utilities import get_fcs_file_paths
from immunova.data.mongo_setup import pd_init
import pandas as pd
import os
pd_init()

# %%
t_pbmc_exp = FCSExperiment.objects(experiment_id='PD_T_PBMCs').get()
t_pdmc_exp = FCSExperiment.objects(experiment_id='PD_T_PDMCs').get()
n_pdmc_exp = FCSExperiment.objects(experiment_id='PD_N_PDMCs').get()
n_pbmc_exp = FCSExperiment.objects(experiment_id='PD_N_PBMCs').get()

# %%
meta = pd.read_excel('pd_metadata.xlsx', sheet_name='All_Data')

# %%
meta = meta[meta.columns[:11]]
meta.head()
# Out:
#     pt_no       status flag cell_origin        dob commenced_pd  \
# 0  142-09  Peritonitis  NaN        PBMC 1950-03-06   2015-06-29
# 1  165-09       Stable  NaN        PBMC 1941-03-17   2013-04-08
# 2  175-09       Stable  NaN        PBMC 1934-04-19   2013-01-29
# 3  209-03  Peritonitis  NaN        PBMC 1948-02-15   2014-05-19
# 4  209-05       Stable  NaN        PBMC 1948-02-15   2014-05-19
#
#   processing_date gender  age_years  age_days  time_on_pd
# 0      2017-09-26      M  67.559206     24676         820
# 1      2017-12-13      M  76.741958     28030        1710
# 2      2018-06-20      M  84.265572     30778        2003
# 3      2017-04-16      M  69.166324     25263        1063
# 4      2017-11-08      M  69.730322     25469        1269

# %%
meta.shape
# Out:
# (104, 11)

# %%
unique_patients = meta.drop(['cell_origin', 'flag', 'processing_date'], axis=1)
unique_patients = unique_patients.drop_duplicates()
unique_patients.head()
# Out:
#     pt_no       status        dob commenced_pd gender  age_years  age_days  \
# 0  142-09  Peritonitis 1950-03-06   2015-06-29      M  67.559206     24676
# 1  165-09       Stable 1941-03-17   2013-04-08      M  76.741958     28030
# 2  175-09       Stable 1934-04-19   2013-01-29      M  84.265572     30778
# 3  209-03  Peritonitis 1948-02-15   2014-05-19      M  69.166324     25263
# 4  209-05       Stable 1948-02-15   2014-05-19      M  69.730322     25469
#
#    time_on_pd
# 0         820
# 1        1710
# 2        2003
# 3        1063
# 4        1269

# %%
len(set(unique_patients.pt_no.values))
# Out:
# 57

# %%
unique_patients.shape[0]
# Out:
# 57

# %% [markdown]
# <h1>Create patient objects</h1>

# %%
def check_null(x):
    if pd.isna(x):
        return None
    return x

def process_gender(g):
    if g == 'M':
        return 0
    if g == 'F':
        return 1
    return None

def create_patient(r):
    patient = Patient()
    patient.patient_id = check_null(r.pt_no)
    patient.status = check_null(r.status)
    patient.dob = check_null(r.dob)
    patient.commenced_pd = check_null(r.commenced_pd)
    patient.gender = process_gender(r.gender)
    patient.age = check_null(r.age_years)
    patient.time_on_pd = check_null(r.time_on_pd)
    return patient

# %%
patients = unique_patients.apply(create_patient, axis=1)

# %% [markdown]
# <h1>Add Microbiology</h1>

# %%
micro = pd.read_excel('pd_metadata.xlsx', sheet_name='Microbiology')
micro.date = micro.date.astype(object).where(micro.date.notnull(), None)
name_key = pd.read_excel('pd_metadata.xlsx', sheet_name='micro_name_key')
code_key = pd.read_excel('pd_metadata.xlsx', sheet_name='micro_codes')

# %%
def get_org_name(org_key):
    if pd.isna(org_key):
        return None
    ref = name_key[name_key.key == org_key]
    if ref.shape[0] == 0:
        print(f'{org_key} does not match any key in reference sheet')
        return org_key
    return ref.name.values[0]

def get_bug_info(code):
    if pd.isna(code):
        return None, None, None
    def check_null(x):
        if pd.isna(x):
            return None
        return x
    ref = code_key[code_key.code == code]
    if ref.shape[0] == 0:
        print(f'{code} not match any code in reference sheet')
        return None, None, None
    return check_null(ref.gram_status.values[0]), check_null(ref.hmbpp.values[0]), check_null(ref.ribo.values[0])
    

def add_micro(patient, micro_ref):
    ref = micro_ref[micro_ref.pt_id == patient.patient_id]
    if ref.shape[0] != 0:
        data = ref.to_dict('records')
    else:
        return patient
    bugs = list()
    for x in data:
        gram, hmbpp, ribo = get_bug_info(x['code'])
        new_bug = Bug(org_name=get_org_name(x['org']),
                     report_date=x['date'],
                     gram_status=gram,
                     hmbpp_status=hmbpp)
        bugs.append(new_bug)
    patient.infection_data = bugs
    return patient

# %%
patients_with_micro = list()
for p in patients:
    patients_with_micro.append(add_micro(p, micro))

# %%
for p in patients:
    p.save()

# %% [markdown]
# <h1>Add Flow Cytometry Data</h1>

# %%
def fetch_files(patient_id, status):
    n_ctrl_names = ['CD1c', 'HLA-DR']
    t_ctrl_names = ['CXCR3', 'CD27', 'CD45RA', 'CCR7']
    root = f'/media/ross/extdrive/PD_DS_Friendly/{status}/{patient_id}/'
    if not os.path.isdir(root):
        print(f'No file directory found for patient {patient_id} with status {status}')
        return None
    # PBMC_N
    pbmc_n = get_fcs_file_paths(f'{root}PBMC_N', n_ctrl_names, 'FMO')
    # PBMC_T
    pbmc_t = get_fcs_file_paths(f'{root}PBMC_T', t_ctrl_names, 'FMO')
    # PDMC_N
    pdmc_n = get_fcs_file_paths(f'{root}PDMC_N', n_ctrl_names, 'FMO')
    # PDMC_T
    pdmc_t = get_fcs_file_paths(f'{root}PDMC_T', t_ctrl_names, 'FMO')
    
    return dict(pdmc_n=pdmc_n, pdmc_t=pdmc_t, pbmc_n=pbmc_n, pbmc_t=pbmc_t)

def add_flow_data(patient):
    patient_id = patient.patient_id
    status = patient.status
    print(f'----------------------- {patient_id} -----------------------')
    files = fetch_files(patient_id, status)
    if files is None:
        return
    # Add PBMC files
    # T panel
    if len(files['pbmc_t']['primary']) == 1:
        t_pbmc_exp.add_new_sample(sample_id=f'{patient_id}_pbmc_t',
                                 file_path=files['pbmc_t']['primary'][0],
                                 controls=files['pbmc_t']['controls'],
                                 patient_id=patient_id)
    else:
        print(f'Check PBMC T panel files for {patient_id} manually')
    # N panel
    if len(files['pbmc_n']['primary']) == 1:
        n_pbmc_exp.add_new_sample(sample_id=f'{patient_id}_pbmc_n',
                                 file_path=files['pbmc_n']['primary'][0],
                                 controls=files['pbmc_n']['controls'],
                                 patient_id=patient_id)
    else:
        print(f'Check PBMC N panel files for {patient_id} manually')
    # Add PDMC files
    # T panel
    if len(files['pdmc_t']['primary']) == 1:
        t_pdmc_exp.add_new_sample(sample_id=f'{patient_id}_pdmc_t',
                                 file_path=files['pdmc_t']['primary'][0],
                                 controls=files['pdmc_t']['controls'],
                                 patient_id=patient_id)
    else:
        print(f'Check PDMC T panel files for {patient_id} manually')
    # N panel
    if len(files['pdmc_n']['primary']) == 1:
        n_pdmc_exp.add_new_sample(sample_id=f'{patient_id}_pdmc_n',
                                 file_path=files['pdmc_n']['primary'][0],
                                 controls=files['pdmc_n']['controls'],
                                 patient_id=patient_id)
    else:
        print(f'Check PDMC N panel files for {patient_id} manually')
    print(f'{patient_id} complete')

# %%
for p in patients:
    add_flow_data(p)
# Out:
# ----------------------- 142-09 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD27 control
# Generating main file entry...
# Missing channel FSC-W
# Missing channel SSC-H
# Generating file entries for controls...
# Successfully created 142-09_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 142-09 manually
# Generating main file entry...
# Missing channel FSC-W
# Missing channel SSC-H
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel SSC-H
# Missing channel FSC-W
# Missing channel SSC-H
# Missing channel FSC-W
# Missing channel SSC-H
# Successfully created 142-09_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 142-09_pdmc_n and associated to PD_N_PDMCs
# 142-09 complete
# ----------------------- 165-09 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 165-09_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 165-09 manually
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Successfully created 165-09_pdmc_t and associated to PD_T_PDMCs
# Check PDMC N panel files for 165-09 manually
# 165-09 complete
# ----------------------- 175-09 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Successfully created 175-09_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 175-09 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 175-09_pdmc_t and associated to PD_T_PDMCs
# Check PDMC N panel files for 175-09 manually
# 175-09 complete
# ----------------------- 209-03 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Check PBMC T panel files for 209-03 manually
# Check PBMC N panel files for 209-03 manually
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 209-03_pdmc_t and associated to PD_T_PDMCs
# Check PDMC N panel files for 209-03 manually
# 209-03 complete
# ----------------------- 209-05 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Check PBMC T panel files for 209-05 manually
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Successfully created 209-05_pbmc_n and associated to PD_N_PBMCs
# Generating main file entry...
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# Generating file entries for controls...
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# Successfully created 209-05_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Successfully created 209-05_pdmc_n and associated to PD_N_PDMCs
# 209-05 complete
# ----------------------- 210-12 -----------------------
# No file directory found for patient 210-12 with status Peritonitis
# ----------------------- 210-14 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 210-14_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 210-14 manually
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 210-14_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 210-14_pdmc_n and associated to PD_N_PDMCs
# 210-14 complete
# ----------------------- 229-02 -----------------------
# No file directory found for patient 229-02 with status Stable
# ----------------------- 239-02 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 239-02_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 239-02 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 239-02_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 239-02_pdmc_n and associated to PD_N_PDMCs
# 239-02 complete
# ----------------------- 239-04 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 239-04_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 239-04 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 239-04_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 239-04_pdmc_n and associated to PD_N_PDMCs
# 239-04 complete
# ----------------------- 251-07 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD45RA control
# Warning! Multiple non-control (primary) files found in directory. Check before proceeding.
# Check PBMC T panel files for 251-07 manually
# Check PBMC N panel files for 251-07 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 251-07_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 251-07_pdmc_n and associated to PD_N_PDMCs
# 251-07 complete
# ----------------------- 251-08 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Successfully created 251-08_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 251-08 manually
# Generating main file entry...
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 251-08_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 251-08_pdmc_n and associated to PD_N_PDMCs
# 251-08 complete
# ----------------------- 254-04 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 254-04_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 254-04 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 254-04_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 254-04_pdmc_n and associated to PD_N_PDMCs
# 254-04 complete
# ----------------------- 254-05 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 254-05_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 254-05 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 254-05_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 254-05_pdmc_n and associated to PD_N_PDMCs
# 254-05 complete
# ----------------------- 255-04 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 255-04_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 255-04 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 255-04_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 255-04_pdmc_n and associated to PD_N_PDMCs
# 255-04 complete
# ----------------------- 255-05 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 255-05_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 255-05 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 255-05_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 255-05_pdmc_n and associated to PD_N_PDMCs
# 255-05 complete
# ----------------------- 262-01 -----------------------
# No file directory found for patient 262-01 with status Peritonitis
# ----------------------- 264-02 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 264-02_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 264-02 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 264-02_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 264-02_pdmc_n and associated to PD_N_PDMCs
# 264-02 complete
# ----------------------- 267-02 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Check PBMC T panel files for 267-02 manually
# Check PBMC N panel files for 267-02 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 267-02_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 267-02_pdmc_n and associated to PD_N_PDMCs
# 267-02 complete
# ----------------------- 272-01 -----------------------
# No file directory found for patient 272-01 with status Stable
# ----------------------- 273-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 273-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 273-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 273-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 273-01_pdmc_n and associated to PD_N_PDMCs
# 273-01 complete
# ----------------------- 276-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 276-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 276-01 manually
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 276-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 276-01_pdmc_n and associated to PD_N_PDMCs
# 276-01 complete
# ----------------------- 286-03 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 286-03_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 286-03 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 286-03_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 286-03_pdmc_n and associated to PD_N_PDMCs
# 286-03 complete
# ----------------------- 286-04 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 286-04_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 286-04 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 286-04_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 286-04_pdmc_n and associated to PD_N_PDMCs
# 286-04 complete
# ----------------------- 294-02 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Missing channel FSC-W
# Missing channel SSC-H
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel SSC-H
# Missing channel FSC-W
# Missing channel SSC-H
# Missing channel FSC-W
# Missing channel SSC-H
# Missing channel FSC-W
# Missing channel SSC-H
# Successfully created 294-02_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 294-02 manually
# Generating main file entry...
# Missing channel FSC-W
# Missing channel SSC-H
# Generating file entries for controls...
# Successfully created 294-02_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 294-02_pdmc_n and associated to PD_N_PDMCs
# 294-02 complete
# ----------------------- 294-03 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 294-03_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 294-03 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 294-03_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 294-03_pdmc_n and associated to PD_N_PDMCs
# 294-03 complete
# ----------------------- 295-01 -----------------------
# No file directory found for patient 295-01 with status Peritonitis
# ----------------------- 298-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 298-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 298-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 298-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 298-01_pdmc_n and associated to PD_N_PDMCs
# 298-01 complete
# ----------------------- 305-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 305-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 305-01 manually
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 305-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Missing channel FSC-W
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 305-01_pdmc_n and associated to PD_N_PDMCs
# 305-01 complete
# ----------------------- 305-02 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD27 control
# Warning! Multiple non-control (primary) files found in directory. Check before proceeding.
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 305-02_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 305-02 manually
# Check PDMC T panel files for 305-02 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 305-02_pdmc_n and associated to PD_N_PDMCs
# 305-02 complete
# ----------------------- 305-03 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 305-03_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 305-03 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 305-03_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 305-03_pdmc_n and associated to PD_N_PDMCs
# 305-03 complete
# ----------------------- 306-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 306-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 306-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 306-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 306-01_pdmc_n and associated to PD_N_PDMCs
# 306-01 complete
# ----------------------- 308-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 308-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 308-01 manually
# Check PDMC T panel files for 308-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 308-01_pdmc_n and associated to PD_N_PDMCs
# 308-01 complete
# ----------------------- 308-02R -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 308-02R_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 308-02R manually
# Generating main file entry...
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 308-02R_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 308-02R_pdmc_n and associated to PD_N_PDMCs
# 308-02R complete
# ----------------------- 308-03R -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 308-03R_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 308-03R manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 308-03R_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 308-03R_pdmc_n and associated to PD_N_PDMCs
# 308-03R complete
# ----------------------- 308-04 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 308-04_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 308-04 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 308-04_pdmc_t and associated to PD_T_PDMCs
# Check PDMC N panel files for 308-04 manually
# 308-04 complete
# ----------------------- 310-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 310-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 310-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 310-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 310-01_pdmc_n and associated to PD_N_PDMCs
# 310-01 complete
# ----------------------- 315-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 315-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 315-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 315-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 315-01_pdmc_n and associated to PD_N_PDMCs
# 315-01 complete
# ----------------------- 315-02 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 315-02_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 315-02 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 315-02_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 315-02_pdmc_n and associated to PD_N_PDMCs
# 315-02 complete
# ----------------------- 316-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning! Multiple non-control (primary) files found in directory. Check before proceeding.
# Warning: no file found for CXCR3 control
# Warning! Multiple non-control (primary) files found in directory. Check before proceeding.
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 316-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 316-01 manually
# Check PDMC T panel files for 316-01 manually
# Check PDMC N panel files for 316-01 manually
# 316-01 complete
# ----------------------- 318-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 318-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 318-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 318-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 318-01_pdmc_n and associated to PD_N_PDMCs
# 318-01 complete
# ----------------------- 320-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning! Multiple non-control (primary) files found in directory. Check before proceeding.
# Check PBMC T panel files for 320-01 manually
# Check PBMC N panel files for 320-01 manually
# Check PDMC T panel files for 320-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 320-01_pdmc_n and associated to PD_N_PDMCs
# 320-01 complete
# ----------------------- 321-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Check PBMC T panel files for 321-01 manually
# Check PBMC N panel files for 321-01 manually
# Check PDMC T panel files for 321-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 321-01_pdmc_n and associated to PD_N_PDMCs
# 321-01 complete
# ----------------------- 322-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 322-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 322-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 322-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 322-01_pdmc_n and associated to PD_N_PDMCs
# 322-01 complete
# ----------------------- 323-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 323-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 323-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 323-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 323-01_pdmc_n and associated to PD_N_PDMCs
# 323-01 complete
# ----------------------- 323-02 -----------------------
# No file directory found for patient 323-02 with status Peritonitis
# ----------------------- 324-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 324-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 324-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 324-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 324-01_pdmc_n and associated to PD_N_PDMCs
# 324-01 complete
# ----------------------- 326-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 326-01_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 326-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 326-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 326-01_pdmc_n and associated to PD_N_PDMCs
# 326-01 complete
# ----------------------- 237-06 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Check PBMC T panel files for 237-06 manually
# Check PBMC N panel files for 237-06 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 237-06_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 237-06_pdmc_n and associated to PD_N_PDMCs
# 237-06 complete
# ----------------------- 267-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Check PBMC T panel files for 267-01 manually
# Check PBMC N panel files for 267-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 267-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 267-01_pdmc_n and associated to PD_N_PDMCs
# 267-01 complete
# ----------------------- 279-03 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Check PBMC T panel files for 279-03 manually
# Check PBMC N panel files for 279-03 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 279-03_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 279-03_pdmc_n and associated to PD_N_PDMCs
# 279-03 complete
# ----------------------- 286-02 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 286-02_pbmc_t and associated to PD_T_PBMCs
# Check PBMC N panel files for 286-02 manually
# Generating main file entry...
# Generating file entries for controls...
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Missing channel FSC-W
# Successfully created 286-02_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 286-02_pdmc_n and associated to PD_N_PDMCs
# 286-02 complete
# ----------------------- 288-02 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Check PBMC T panel files for 288-02 manually
# Check PBMC N panel files for 288-02 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 288-02_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 288-02_pdmc_n and associated to PD_N_PDMCs
# 288-02 complete
# ----------------------- 289-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Check PBMC T panel files for 289-01 manually
# Check PBMC N panel files for 289-01 manually
# Check PDMC T panel files for 289-01 manually
# Check PDMC N panel files for 289-01 manually
# 289-01 complete
# ----------------------- 294-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Check PBMC T panel files for 294-01 manually
# Check PBMC N panel files for 294-01 manually
# Generating main file entry...
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# Missing channel FSC-W
# Missing channel SSC-H
# Generating file entries for controls...
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# Missing channel FSC-W
# Missing channel SSC-H
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# Missing channel FSC-W
# Missing channel SSC-H
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# Missing channel FSC-W
# Missing channel SSC-H
# The channel/marker pairing Alexa Fluor 405-A/CD27 does not correspond to any defined in panel
# The channel/marker pairing PE-Cy7-A/CCR7 does not correspond to any defined in panel
# Missing channel FSC-W
# Missing channel SSC-H
# Successfully created 294-01_pdmc_t and associated to PD_T_PDMCs
# Check PDMC N panel files for 294-01 manually
# 294-01 complete
# ----------------------- 302-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Check PBMC T panel files for 302-01 manually
# Check PBMC N panel files for 302-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 302-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 302-01_pdmc_n and associated to PD_N_PDMCs
# 302-01 complete
# ----------------------- 307-01 -----------------------
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Warning: no file found for CD1c control
# Warning: no file found for HLA-DR control
# Warning: no file found for CXCR3 control
# Warning: no file found for CD27 control
# Warning: no file found for CD45RA control
# Warning: no file found for CCR7 control
# Check PBMC T panel files for 307-01 manually
# Check PBMC N panel files for 307-01 manually
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 307-01_pdmc_t and associated to PD_T_PDMCs
# Generating main file entry...
# Generating file entries for controls...
# Successfully created 307-01_pdmc_n and associated to PD_N_PDMCs
# 307-01 complete
