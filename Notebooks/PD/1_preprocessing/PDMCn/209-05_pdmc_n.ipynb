# %%
from warnings import simplefilter
simplefilter("ignore", category=FutureWarning) 
simplefilter("ignore", category=UserWarning)
import sys
if '/home/rossco/immunova' not in sys.path:
    sys.path.append('/home/rossco/immunova')
from apply_template import apply_n_template
from immunova.data.mongo_setup import pd_init
pd_init()

# %%
t = apply_n_template(sample_id='209-05_pdmc_n')
# Out:
# Applying boundary...
# ------ boundary ------
# New population: cells
# ...proportion of total events: 0.433
# ...proportion of parent: 0.433
# New population: debris
# ...proportion of total events: 0.567
# ...proportion of parent: 0.567
# -----------------------
# Applying CD45_gate...
# ------ CD45_gate ------
# New population: CD45+
# ...proportion of total events: 0.022
# ...proportion of parent: 0.050
# New population: CD45-
# ...proportion of total events: 0.411
# ...proportion of parent: 0.950
# -----------------------
# Applying live_gate...
# ------ live_gate ------
# New population: dead
# ...proportion of total events: 0.001
# ...proportion of parent: 0.050
# New population: Live_CD45+
# ...proportion of total events: 0.021
# ...proportion of parent: 0.949
# -----------------------
# Applying singlets_gate...
# ------ singlets_gate ------
# New population: doublets
# ...proportion of total events: 0.002
# ...proportion of parent: 0.100
# New population: Single_Live_CD45+
# ...proportion of total events: 0.018
# ...proportion of parent: 0.899
# -----------------------
# Complete!

# %%
t.save(overwrite=True)
# Out:
# Saved successfully!
# True

# %%
f = t.filegroup

# %%
f.flags = 'invalid'

# %%
f.save()
# Out:
# <FileGroup: FileGroup object>
