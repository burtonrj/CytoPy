# %%
from warnings import simplefilter
simplefilter("ignore", category=FutureWarning) 
simplefilter("ignore", category=UserWarning)
import sys
if '/home/rossco/immunova' not in sys.path:
    sys.path.append('/home/rossco/immunova')
from apply_template import apply_n_template
from immunova.data.mongo_setup import pd_init
pd_init()

# %%
t = apply_n_template(sample_id='273-01_pdmc_n')
# Out:
# Applying boundary...
# ------ boundary ------
# New population: cells
# ...proportion of total events: 0.918
# ...proportion of parent: 0.918
# New population: debris
# ...proportion of total events: 0.082
# ...proportion of parent: 0.082
# -----------------------
# Applying CD45_gate...
# ------ CD45_gate ------
# New population: CD45+
# ...proportion of total events: 0.866
# ...proportion of parent: 0.944
# New population: CD45-
# ...proportion of total events: 0.052
# ...proportion of parent: 0.056
# -----------------------
# Applying live_gate...
# ------ live_gate ------
# New population: dead
# ...proportion of total events: 0.044
# ...proportion of parent: 0.050
# New population: Live_CD45+
# ...proportion of total events: 0.823
# ...proportion of parent: 0.950
# -----------------------
# Applying singlets_gate...
# ------ singlets_gate ------
# New population: doublets
# ...proportion of total events: 0.082
# ...proportion of parent: 0.100
# New population: Single_Live_CD45+
# ...proportion of total events: 0.740
# ...proportion of parent: 0.900
# -----------------------
# Complete!

# %%
t.save(overwrite=True)
# Out:
# Saved successfully!
# True
