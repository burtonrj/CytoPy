# %%
from warnings import simplefilter
simplefilter("ignore", category=FutureWarning) 
simplefilter("ignore", category=UserWarning)
import sys
if '/home/rossco/immunova' not in sys.path:
    sys.path.append('/home/rossco/immunova')
from apply_template import apply_n_template
from immunova.data.mongo_setup import pd_init
pd_init()

# %%
t = apply_n_template(sample_id='251-07_pdmc_n')
# Out:
# Applying boundary...
# ------ boundary ------
# New population: cells
# ...proportion of total events: 0.946
# ...proportion of parent: 0.946
# New population: debris
# ...proportion of total events: 0.054
# ...proportion of parent: 0.054
# -----------------------
# Applying CD45_gate...
# ------ CD45_gate ------
# New population: CD45+
# ...proportion of total events: 0.641
# ...proportion of parent: 0.678
# New population: CD45-
# ...proportion of total events: 0.304
# ...proportion of parent: 0.322
# -----------------------
# Applying live_gate...
# ------ live_gate ------
# New population: dead
# ...proportion of total events: 0.035
# ...proportion of parent: 0.055
# New population: Live_CD45+
# ...proportion of total events: 0.606
# ...proportion of parent: 0.945
# -----------------------
# Applying singlets_gate...
# ------ singlets_gate ------
# New population: doublets
# ...proportion of total events: 0.061
# ...proportion of parent: 0.100
# New population: Single_Live_CD45+
# ...proportion of total events: 0.545
# ...proportion of parent: 0.900
# -----------------------
# Complete!

# %%
t.save(overwrite=True)
# Out:
# Saved successfully!
# True
