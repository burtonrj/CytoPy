# %%
from warnings import simplefilter
simplefilter("ignore", category=FutureWarning) 
simplefilter("ignore", category=UserWarning)
import sys
if '/home/rossco/immunova' not in sys.path:
    sys.path.append('/home/rossco/immunova')
from apply_template import apply_n_template
from immunova.data.mongo_setup import pd_init
pd_init()

# %%
t = apply_n_template(sample_id='286-04_pdmc_n')
# Out:
# Applying boundary...
# ------ boundary ------
# New population: cells
# ...proportion of total events: 0.942
# ...proportion of parent: 0.942
# New population: debris
# ...proportion of total events: 0.058
# ...proportion of parent: 0.058
# -----------------------
# Applying CD45_gate...
# ------ CD45_gate ------
# New population: CD45+
# ...proportion of total events: 0.048
# ...proportion of parent: 0.051
# New population: CD45-
# ...proportion of total events: 0.894
# ...proportion of parent: 0.949
# -----------------------
# Applying live_gate...
# ------ live_gate ------
# New population: dead
# ...proportion of total events: 0.002
# ...proportion of parent: 0.050
# New population: Live_CD45+
# ...proportion of total events: 0.045
# ...proportion of parent: 0.950
# -----------------------
# Applying singlets_gate...
# ------ singlets_gate ------
# New population: doublets
# ...proportion of total events: 0.005
# ...proportion of parent: 0.100
# New population: Single_Live_CD45+
# ...proportion of total events: 0.041
# ...proportion of parent: 0.900
# -----------------------
# Complete!

# %%
p, n = t.fetch_geom('CD45+'), t.fetch_geom('CD45-')
k = 'threshold'
p[k], n[k] = 0.4, 0.4
t.edit_gate('CD45_gate', updated_geom={'CD45+': p, 'CD45-': n})
# Out:
# Editing gate: CD45_gate
# Updating CD45+
# Updating CD45-
# The following gates are downstream of CD45_gate and will need to be applied again: ['live_gate', 'singlets_gate']
# Edit complete!

# %%
t.plotting.plot_gate('CD45_gate')

# %%
t.apply('live_gate')
# Out:
# ------ live_gate ------
# New population: dead
# ...proportion of total events: 0.526
# ...proportion of parent: 0.570
# New population: Live_CD45+
# ...proportion of total events: 0.396
# ...proportion of parent: 0.430
# -----------------------

# %%
p, n = t.fetch_geom('dead'), t.fetch_geom('Live_CD45+')
k = 'threshold'
p[k], n[k] = 0.6, 0.6
t.edit_gate('live_gate', updated_geom={'dead': p, 'Live_CD45+': n})
# Out:
# Editing gate: live_gate
# Updating dead
# Updating Live_CD45+
# The following gates are downstream of live_gate and will need to be applied again: ['singlets_gate']
# Edit complete!

# %%
t.plotting.plot_gate('live_gate')

# %%
t.apply('singlets_gate')
# Out:
# ------ singlets_gate ------
# New population: doublets
# ...proportion of total events: 0.083
# ...proportion of parent: 0.100
# New population: Single_Live_CD45+
# ...proportion of total events: 0.747
# ...proportion of parent: 0.900
# -----------------------

# %%
t.save(overwrite=True)
# Out:
# Saved successfully!
# True
