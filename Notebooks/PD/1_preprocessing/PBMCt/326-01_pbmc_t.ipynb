# %%
import sys
if '/home/rossco/immunova' not in sys.path:
    sys.path.append('/home/rossco/immunova')
from immunova.data.mongo_setup import pd_init
from immunova.data.fcs_experiments import FCSExperiment
from immunova.flow.gating.actions import Gating, Template
from immunova.flow.gating.defaults import ChildPopulationCollection
from warnings import filterwarnings
from tqdm import tqdm_notebook
import matplotlib
import pandas as pd
import os
filterwarnings('ignore')
pd_init()

# %%
texp = FCSExperiment.objects(experiment_id='PD_T_PBMCs').get()

# %%
t = Template(texp, '326-01_pbmc_t', include_controls=False)

# %%
t.load_template('PBMCt_Preprocessing')
# Out:
# True

# %%
t.apply_many(apply_all=True, plot_outcome=True)
# Out:
# Applying boundary...
# ------ boundary ------
# New population: cells
# ...proportion of total events: 0.476
# ...proportion of parent: 0.476
# New population: debris
# ...proportion of total events: 0.524
# ...proportion of parent: 0.524
# -----------------------
# Applying CD3_gate...
# ------ CD3_gate ------
# New population: CD3+
# ...proportion of total events: 0.061
# ...proportion of parent: 0.128
# New population: CD3-
# ...proportion of total events: 0.415
# ...proportion of parent: 0.872
# -----------------------
# Applying live_gate...
# ------ live_gate ------
# New population: dead
# ...proportion of total events: 0.003
# ...proportion of parent: 0.050
# New population: live
# ...proportion of total events: 0.058
# ...proportion of parent: 0.950
# -----------------------
# Applying singlets1_gate...
# ------ singlets1_gate ------
# WARNING: actual population is at least a 3 fold distance from the target. Is this really the population of interest?
# New population: singlets1
# ...proportion of total events: 0.054
# ...proportion of parent: 0.935
# New population: doublets1
# ...proportion of total events: 0.004
# ...proportion of parent: 0.065
# -----------------------
# Applying singlets2_gate...
# ------ singlets2_gate ------
# New population: doublets2
# ...proportion of total events: 0.003
# ...proportion of parent: 0.052
# New population: single_Live_CD3+
# ...proportion of total events: 0.051
# ...proportion of parent: 0.948
# -----------------------
# Applying lymph_gate...
# ------ lymph_gate ------
# WARNING: actual population is at least a 3 fold distance from the target. Is this really the population of interest?
# New population: Lymphocytes
# ...proportion of total events: 0.051
# ...proportion of parent: 0.998
# New population: other cells
# ...proportion of total events: 0.000
# ...proportion of parent: 0.002
# -----------------------
# Complete!

# %%
t.save(overwrite=True)
# Out:
# Saved successfully!
# True
