# %%
from warnings import simplefilter
simplefilter("ignore", category=FutureWarning) 
simplefilter("ignore", category=UserWarning)
import sys
if '/home/rossco/immunova' not in sys.path:
    sys.path.append('/home/rossco/immunova')
from immunova.data.mongo_setup import pd_init
from immunova.data.fcs_experiments import FCSExperiment
from immunova.flow.gating.actions import Gating, Template
from immunova.flow.gating.defaults import ChildPopulationCollection
from tqdm import tqdm_notebook
import matplotlib
import pandas as pd
import os
pd_init()

# %%
texp = FCSExperiment.objects(experiment_id='PD_T_PDMCs').get()

# %%
t = Template(texp, '251-07_pdmc_t', include_controls=False)

# %%
t.load_template('PBMCt_Preprocessing')
# Out:
# True

# %%
t.apply_many(apply_all=True, plot_outcome=True)
# Out:
# Applying boundary...
# ------ boundary ------
# New population: cells
# ...proportion of total events: 0.791
# ...proportion of parent: 0.791
# New population: debris
# ...proportion of total events: 0.209
# ...proportion of parent: 0.209
# -----------------------
# Applying CD3_gate...
# ------ CD3_gate ------
# New population: CD3+
# ...proportion of total events: 0.229
# ...proportion of parent: 0.289
# New population: CD3-
# ...proportion of total events: 0.562
# ...proportion of parent: 0.711
# -----------------------
# Applying live_gate...
# ------ live_gate ------
# New population: dead
# ...proportion of total events: 0.005
# ...proportion of parent: 0.022
# New population: live
# ...proportion of total events: 0.224
# ...proportion of parent: 0.978
# -----------------------
# Applying singlets1_gate...
# ------ singlets1_gate ------
# WARNING: actual population is at least a 3 fold distance from the target. Is this really the population of interest?
# New population: singlets1
# ...proportion of total events: 0.169
# ...proportion of parent: 0.755
# New population: doublets1
# ...proportion of total events: 0.055
# ...proportion of parent: 0.245
# -----------------------
# Applying singlets2_gate...
# ------ singlets2_gate ------
# New population: doublets2
# ...proportion of total events: 0.009
# ...proportion of parent: 0.053
# New population: single_Live_CD3+
# ...proportion of total events: 0.160
# ...proportion of parent: 0.947
# -----------------------
# Applying lymph_gate...
# ------ lymph_gate ------
# WARNING: actual population is at least a 3 fold distance from the target. Is this really the population of interest?
# New population: Lymphocytes
# ...proportion of total events: 0.151
# ...proportion of parent: 0.945
# New population: other cells
# ...proportion of total events: 0.009
# ...proportion of parent: 0.055
# -----------------------
# Complete!

# %%
t.save(overwrite=True)
# Out:
# Saved successfully!
# True
