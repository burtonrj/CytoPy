# %% [markdown]
# <h1>Gating Experiments: FMO KNN</h1>

# %%
from immunova.data.project import Project
from immunova.data.mongo_setup import global_init
from immunova.flow.gating.actions import Template
from tqdm import tqdm_notebook, tqdm
from functools import partial
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
global_init()

# %%
iltis = Project.objects(project_id='ILTIS').get()

# %% [markdown]
# <h2>Create some populations using the T Panel</h2>

# %%
iltis.list_fcs_experiments()
# Out:
# ['t1_exp', 't2_exp', 'n_exp']

# %%
t1_exp = iltis.load_experiment('t1_exp')

# %%
[f.primary_id for f in t1_exp.fcs_files]
# Out:
# ['sep6',
#  'sep12',
#  'sep13',
#  'sep17',
#  'sep19',
#  'sep28',
#  'sep29',
#  'sep34',
#  'sep37',
#  'sep49',
#  'sep50',
#  'sep51',
#  'sep61',
#  'sep67',
#  'sep68']

# %%
t_template = Template(experiment=t1_exp, sample_id='sep6')

# %%
_ = t_template.plot_population('root', x='FSC-A', y='SSC-A')

# %% [markdown]
# <h3>Boundary gate</h3>

# %%
kwargs=dict(x_min=50000, x_max=150000, y_min=0, y_max=100000)
child_populations = dict(cells=dict(definition='+'))
t_template.create_gate(gate_name='cells', parent='root', x='FSC-A', y='SSC-A', 
                       func='rect_gate', func_args=kwargs, gate_type='geom',
                      child_populations=child_populations)
# Out:
# True

# %%
t_template.apply('cells')

# %% [markdown]
# <h3>Lymphocyte gate</h3>

# %%
_ = t_template.plot_population('cells', x='FSC-A', y='SSC-A')

# %%
kwargs=dict(target=(100000,50000), k=3, conf=0.99)
child_populations = dict(lymphocytes=dict(definition='+'))
t_template.create_gate(gate_name='lymphocytes', parent='cells',x='FSC-A', 
                       y='SSC-A', func='mm_gate', func_args=kwargs, gate_type='geom',
                      child_populations=child_populations)
# Out:
# True

# %%
t_template.apply('lymphocytes')

# %% [markdown]
# <h3>Singlet gate</h3>

# %%
_ = t_template.plot_population('lymphocytes', x='FSC-A', y='FSC-H', xlim=(30000,155000), ylim=(30000,150000))

# %%
kwargs=dict(target=(100000,80000), k=2, conf=0.99)
child_populations = dict(singlets=dict(definition='+'))
t_template.create_gate(gate_name='singlets', parent='lymphocytes', x='FSC-A',
                      y='FSC-H', func='mm_gate', func_args=kwargs, gate_type='geom',
                      child_populations=child_populations)
# Out:
# True

# %%
t_template.apply('singlets')

# %%
_ = t_template.plot_gate('singlets', xlim=(30000,150000), ylim=(30000,125000))

# %%
_ = t_template.plot_population('singlets', x='SSC-W', y='FSC-A')

# %%
kwargs=dict(q=0.95)
child_populations = dict(singlets_w=dict(definition='+'), doublets=dict(definition='-'))
t_template.create_gate(gate_name='singlets2', parent='singlets', x='SSC-W',
                       func='quantile_gate', func_args=kwargs, gate_type='threshold',
                      child_populations=child_populations)
# Out:
# True

# %%
t_template.apply('singlets2')

# %%
_ = t_template.plot_gate('singlets2', xlim=(50000,150000), ylim=(50000, 125000))

# %% [markdown]
# <h3>Live/Dead Gate</h3>

# %%
_ = t_template.plot_population('singlets_w', x='L/D', y='FSC-A')

# %%
kwargs=dict(q=0.9, kde_bw=0.1, kde_sample_frac=0.5, ignore_double_pos=False, 
            peak_threshold=0.01)
child_populations = dict(dead=dict(definition='+'), live=dict(definition='-'))
t_template.create_gate(gate_name='livedead_gate', parent='singlets_w', x='L/D',
                       func='density_gate_1d', func_args=kwargs, gate_type='geom', child_populations=child_populations)
# Out:
# True

# %%
t_template.apply('livedead_gate')

# %% [markdown]
# <h3>T Cells (CD3+)</h3>

# %%
kwargs=dict(q=0.95, kde_bw=0.1, kde_sample_frac=1, ignore_double_pos=True, 
            peak_threshold=0.05)
child_populations = {'cd3+': dict(definition='+'), 'cd3-': dict(definition='-')}
t_template.create_gate(gate_name='cd3_gate', child_populations=child_populations, parent='live', x='CD3',
                       func='density_gate_1d', func_args=kwargs, gate_type='geom')
# Out:
# True

# %%
t_template.apply('cd3_gate')

# %% [markdown]
# <h3>Gamma Delta T cells</h3>

# %%
_ = t_template.plot_population('cd3+', x='Vd2', y='PanGD')

# %%
kwargs=dict(min_pop_size=3, distance_nn=0.05, core_only=False, nn=15)
child_populations={'gdt': {'target': (0.9, 0.6), 'weight': 0},
                   'non_gdt': {'target': (0.3, 0.1), 'weight': 1}}
t_template.create_gate(gate_name='gdt_gate', child_populations=child_populations, parent='cd3+', x='Vd2',
                       y='PanGD', func='dbscan_gate', func_args=kwargs, gate_type='cluster')
# Out:
# True

# %%
t_template.apply('gdt_gate')

# %% [markdown]
# <h3>MAITs</h3>

# %%
_ = t_template.plot_population('non_gdt', x='Va7.2', y='CD161')

# %%
kwargs=dict(min_pop_size=3, distance_nn=0.05, core_only=False)
child_populations={'mait': {'target': (0.9, 0.6), 'weight': 0},
                   'classic_tcells': {'target': (0.2, 0.2), 'weight': 1}}
t_template.create_gate(gate_name='mait_gate', child_populations=child_populations, parent='non_gdt', x='Va7.2',
                       y='CD161', func='dbscan_gate', func_args=kwargs, gate_type='cluster')
# Out:
# True

# %%
t_template.apply('mait_gate')
# Out:
# Population mait not recognised

# %% [markdown]
# <h3>Classic T cells</h3>

# %%
_ = t_template.plot_population('classic_tcells', x='CD4', y='CD8')

# %%
kwargs=dict(min_pop_size=10, distance_nn=0.05, core_only=False)
child_populations={'cd4': {'target': (0.8, 0.2), 'weight': 1},
                   'cd8': {'target': (0.2, 0.8), 'weight': 1}}
t_template.create_gate(gate_name='cd4cd8_gate', child_populations=child_populations, parent='classic_tcells', 
                       x='CD4', y='CD8', func='dbscan_gate', func_args=kwargs, gate_type='cluster')
# Out:
# True

# %%
t_template.apply('cd4cd8_gate')

# %%
results = []
for name, data in t_template.populations.items():
    results.append(dict(pt_id=t_template.id, name=name, parent=data['parent'], prop_of_parent=data['prop_of_parent'],
                       prop_of_total=data['prop_of_total']))

# %%
results = pd.DataFrame(results)
all_results = pd.read_csv('experiment_data/auto_gate_results.csv')
all_results = pd.concat([all_results, results])
all_results.to_csv('experiment_data/auto_gate_results.csv', index=False)

# %%
type(t_template.populations['singlets']['geom']['mean'][0])
# Out:
# numpy.float64

# %%
import numpy as np
np.float64(t_template.populations['singlets_w']['geom']['threshold'])
# Out:
# 73420.78125

# %%
t_template.populations
# Out:
# {'root': {'population_name': 'root',
#   'prop_of_parent': 1.0,
#   'prop_of_total': 1.0,
#   'warnings': [],
#   'parent': 'NA',
#   'children': ['cells'],
#   'geom': {},
#   'index': array([      0,       1,       2, ..., 1004935, 1004936, 1004937])},
#  'cells': {'population_name': 'cells',
#   'index': array([      2,       3,       4, ..., 1004934, 1004935, 1004937]),
#   'prop_of_parent': 0.6371268675281461,
#   'prop_of_total': 0.6371268675281461,
#   'parent': 'root',
#   'children': ['lymphocytes'],
#   'geom': {'x_min': 50000,
#    'x_max': 150000,
#    'y_min': 0,
#    'y_max': 100000,
#    'shape': 'rect',
#    'x': 'FSC-A',
#    'y': 'SSC-A'},
#   'warnings': []},
#  'lymphocytes': {'population_name': 'lymphocytes',
#   'index': array([      5,       9,      14, ..., 1004930, 1004933, 1004935]),
#   'prop_of_parent': 0.3102848316265093,
#   'prop_of_total': 0.1976908028156961,
#   'parent': 'cells',
#   'children': ['singlets'],
#   'geom': {'mean': (88050.2561781061, 50831.02405775888),
#    'width': 84277.76620297701,
#    'height': 104574.84359053892,
#    'angle': 163.40520083716018,
#    'shape': 'ellipse',
#    'x': 'FSC-A',
#    'y': 'SSC-A'},
#   'warnings': ['WARNING: actual population is at least a 3 fold distance from the target. Is this really the population of interest?']},
#  'singlets': {'population_name': 'singlets',
#   'index': array([      5,       9,      14, ..., 1004930, 1004933, 1004935]),
#   'prop_of_parent': 0.8900471643503954,
#   'prop_of_total': 0.17595413846426347,
#   'parent': 'lymphocytes',
#   'children': ['singlets_w', 'doublets'],
#   'geom': {'mean': (97183.80344615113, 80006.79531928938),
#    'width': 15466.158904466685,
#    'height': 77846.89279130896,
#    'angle': 128.81580544037377,
#    'shape': 'ellipse',
#    'x': 'FSC-A',
#    'y': 'FSC-H'},
#   'warnings': ['WARNING: actual population is at least a 3 fold distance from the target. Is this really the population of interest?']},
#  'singlets_w': {'population_name': 'singlets_w',
#   'index': array([    141,     301,     329, ..., 1004641, 1004728, 1004799]),
#   'prop_of_parent': 0.05000480706695396,
#   'prop_of_total': 0.008798552746537597,
#   'parent': 'singlets',
#   'children': ['dead', 'live'],
#   'geom': {'threshold': 73420.78,
#    'method': 'quantile',
#    'shape': 'threshold',
#    'x': 'SSC-W',
#    'y': None},
#   'warnings': []},
#  'doublets': {'population_name': 'doublets',
#   'index': array([      5,       9,      14, ..., 1004930, 1004933, 1004935]),
#   'prop_of_parent': 0.949995192933046,
#   'prop_of_total': 0.16715558571772587,
#   'parent': 'singlets',
#   'children': [],
#   'geom': {'threshold': 73420.78,
#    'method': 'quantile',
#    'shape': 'threshold',
#    'x': 'SSC-W',
#    'y': None},
#   'warnings': []},
#  'dead': {'population_name': 'dead',
#   'index': array([    784,    3480,    4753,    5382,    7155,    9641,    9874,
#            12441,   14346,   15116,   17067,   17201,   17299,   19159,
#            21639,   23093,   23696,   24768,   26790,   30172,   30560,
#            31228,   31330,   32984,   33008,   33926,   34206,   35662,
#            35746,   36091,   36148,   37090,   37551,   38101,   40097,
#            40317,   40643,   41604,   42962,   43060,   48606,   48893,
#            49909,   50629,   53050,   54976,   55744,   57258,   59599,
#            61705,   62373,   63087,   66388,   70136,   71172,   72378,
#            72725,   73102,   73420,   74405,   76279,   78208,   79393,
#            80218,   81778,   83007,   84695,   87602,   88220,   89349,
#            90551,   90727,   92415,   93215,   94163,   94996,   96541,
#            98745,   98746,  101808,  106242,  107477,  107700,  108111,
#           108832,  110770,  112799,  114271,  114903,  118413,  119144,
#           120538,  120585,  122605,  124125,  124189,  126263,  126287,
#           126938,  127396,  128718,  128928,  129062,  129263,  129894,
#           130300,  131047,  132044,  134220,  135569,  135629,  136275,
#           137522,  137573,  137738,  139172,  140977,  145144,  145523,
#           145922,  146742,  149688,  154395,  155342,  156423,  158388,
#           158977,  160243,  162716,  162723,  163399,  163520,  164146,
#           164202,  167855,  171185,  173022,  181604,  182929,  183542,
#           183972,  184051,  184422,  187181,  189276,  194660,  194749,
#           196104,  200302,  202864,  205219,  205317,  206073,  206225,
#           207488,  208161,  210296,  213249,  214041,  214577,  215368,
#           216080,  218999,  219175,  219393,  222215,  223146,  223904,
#           224938,  229831,  229941,  229959,  230025,  230585,  234178,
#           235576,  236069,  236130,  236321,  237300,  239589,  244522,
#           245675,  245682,  245811,  246714,  247654,  248008,  248529,
#           251095,  252802,  253484,  253710,  254856,  255537,  257363,
#           258639,  259931,  260847,  263225,  269141,  269744,  270089,
#           270869,  271060,  271335,  277372,  278000,  278699,  280828,
#           281071,  281601,  281831,  282730,  283647,  285413,  286564,
#           287811,  288810,  290071,  290357,  290459,  290681,  291139,
#           293533,  295186,  296367,  297295,  297754,  298370,  301960,
#           302071,  303111,  305629,  306316,  308864,  310280,  310934,
#           311529,  313931,  315299,  315310,  317298,  318840,  319947,
#           320400,  321157,  322046,  323480,  324555,  324670,  325978,
#           326110,  328291,  328453,  330472,  331394,  331714,  332141,
#           332283,  332961,  336882,  337213,  339655,  341239,  342270,
#           343183,  345079,  345502,  345529,  345761,  348248,  348474,
#           348892,  349035,  350826,  350947,  352688,  352870,  353416,
#           358001,  358343,  358497,  359561,  359831,  363639,  363811,
#           366199,  370415,  371250,  372234,  372269,  372400,  373201,
#           374348,  374383,  374459,  374718,  377426,  379098,  379794,
#           382283,  383453,  385207,  385737,  387348,  388024,  388231,
#           388597,  389068,  389657,  391978,  392978,  393640,  395213,
#           396542,  400394,  402152,  403111,  403337,  405178,  406689,
#           409053,  411134,  414407,  414542,  418066,  422364,  423375,
#           425989,  426067,  428345,  430701,  431812,  432071,  433011,
#           433221,  433973,  434525,  435272,  435328,  436215,  436828,
#           437018,  438327,  439286,  441271,  441281,  442630,  444139,
#           444710,  444800,  444958,  446292,  446977,  448440,  448898,
#           449273,  451043,  455290,  456160,  459934,  459962,  460656,
#           461241,  461838,  465102,  466808,  466837,  466972,  468202,
#           468796,  471793,  472177,  476872,  476908,  477716,  477886,
#           478928,  481382,  481688,  482268,  484759,  485243,  485530,
#           492866,  497118,  499966,  500651,  501795,  502867,  503819,
#           505004,  510067,  510102,  514980,  515628,  516482,  516487,
#           516570,  518201,  518202,  518676,  520316,  521616,  522027,
#           525746,  527664,  529275,  529803,  529893,  531378,  533648,
#           534226,  537897,  538861,  539253,  539390,  540626,  542331,
#           542394,  543771,  544895,  545447,  548682,  549806,  552257,
#           552738,  553085,  553749,  553849,  554090,  554718,  555594,
#           556716,  558215,  561893,  563963,  564938,  567407,  567636,
#           568919,  569901,  571209,  571563,  572284,  574614,  576622,
#           577507,  578684,  580068,  580640,  581157,  581538,  584284,
#           586425,  587505,  587530,  589175,  590279,  590305,  592429,
#           593363,  593461,  593646,  594661,  594782,  595953,  599113,
#           599513,  599930,  600017,  603212,  603579,  603901,  605049,
#           605740,  605838,  607531,  607673,  610369,  610724,  610999,
#           613182,  613774,  613981,  615482,  616570,  619751,  625137,
#           625542,  626092,  626893,  628250,  629110,  629365,  629952,
#           631686,  632069,  633368,  633582,  635385,  636347,  636353,
#           636583,  636829,  638734,  638737,  640213,  640338,  641491,
#           642413,  642727,  642814,  642922,  644704,  646382,  647735,
#           648428,  648433,  648744,  652966,  657686,  658287,  659179,
#           660524,  660724,  662245,  664404,  665021,  666169,  667530,
#           670742,  673858,  674099,  675129,  676065,  676643,  677680,
#           678058,  678619,  678761,  680587,  683975,  684602,  684841,
#           685813,  686139,  686838,  687158,  687431,  687442,  687535,
#           689807,  691524,  697260,  697482,  697800,  700332,  701589,
#           701978,  703586,  703752,  706443,  707133,  707297,  709432,
#           709689,  710129,  712561,  713309,  713674,  715042,  715122,
#           715836,  716356,  717661,  718488,  720037,  721668,  722637,
#           728824,  729324,  730709,  730793,  731803,  732464,  732736,
#           739571,  740340,  741156,  741576,  741577,  742126,  742348,
#           742743,  744907,  745533,  746538,  751073,  751792,  753358,
#           753468,  754048,  754664,  754804,  755752,  757751,  758029,
#           758034,  758069,  759036,  759057,  763608,  764700,  765663,
#           766166,  766419,  767054,  769659,  769850,  769866,  771376,
#           773085,  773271,  774791,  774869,  776234,  776468,  776686,
#           778424,  778996,  780380,  780385,  781147,  781746,  782018,
#           782707,  783265,  784286,  786475,  786572,  786681,  787408,
#           787750,  787766,  788596,  788651,  788702,  789276,  791292,
#           792224,  794330,  795766,  795997,  796471,  798146,  800105,
#           800863,  802764,  802940,  803940,  804503,  804876,  804937,
#           805531,  806137,  806627,  808082,  808173,  808487,  808550,
#           810357,  813322,  814460,  814824,  816840,  820110,  821269,
#           821304,  824913,  824978,  825109,  825884,  827583,  830138,
#           830857,  831293,  831312,  832191,  832683,  834694,  837343,
#           841992,  842171,  842257,  843533,  843912,  845925,  846306,
#           849021,  851037,  851610,  852843,  852992,  853690,  854757,
#           855666,  856338,  857647,  859418,  860416,  860500,  861522,
#           864346,  864445,  864614,  865414,  865695,  866295,  867019,
#           867118,  867173,  867464,  867944,  868220,  871529,  872154,
#           873071,  874142,  874501,  875081,  875155,  875402,  876314,
#           877198,  878409,  879194,  880361,  881457,  881581,  882188,
#           882637,  883408,  883709,  885245,  887262,  890840,  891021,
#           891254,  891363,  894556,  896131,  897284,  897494,  897940,
#           898496,  899344,  899657,  900285,  901926,  902110,  902837,
#           903521,  904161,  906650,  907810,  909220,  909636,  910395,
#           910535,  910619,  912050,  914139,  914327,  916149,  916317,
#           917092,  918925,  919520,  919850,  920081,  921886,  923492,
#           923603,  925072,  925354,  925959,  926817,  928078,  929617,
#           930531,  932398,  933411,  935139,  935170,  935262,  935423,
#           936374,  936732,  937947,  939295,  941564,  943276,  943410,
#           943450,  943841,  946391,  948676,  949011,  949856,  951439,
#           951830,  952101,  952634,  953412,  953549,  955024,  955181,
#           956055,  957339,  957371,  958158,  958457,  958558,  958789,
#           959508,  959717,  960108,  961580,  962535,  963120,  964075,
#           964535,  964932,  965202,  965335,  965724,  968586,  969379,
#           969744,  969872,  971110,  972439,  973605,  974897,  975480,
#           976582,  976608,  976616,  977270,  977356,  977795,  979396,
#           979830,  981179,  981229,  981413,  981629,  981791,  983972,
#           984228,  984310,  986598,  986656,  987216,  987639,  988017,
#           988219,  991011,  991637,  992871,  992907,  994478,  994854,
#           994943,  995089,  996386,  997689, 1000480, 1001316, 1002430,
#          1002442, 1003154, 1004233]),
#   'prop_of_parent': 0.10009047726758652,
#   'prop_of_total': 0.0008806513436649823,
#   'parent': 'singlets_w',
#   'children': [],
#   'geom': {'method': '>= None Standard Devs',
#    'threshold': 0.5327923040377214,
#    'shape': 'threshold',
#    'x': 'L/D',
#    'y': None},
#   'warnings': []},
#  'live': {'population_name': 'live',
#   'index': array([    141,     301,     329, ..., 1004641, 1004728, 1004799]),
#   'prop_of_parent': 0.8999095227324135,
#   'prop_of_total': 0.007917901402872615,
#   'parent': 'singlets_w',
#   'children': ['cd3+', 'cd3-'],
#   'geom': {'method': '>= None Standard Devs',
#    'threshold': 0.5327923040377214,
#    'shape': 'threshold',
#    'x': 'L/D',
#    'y': None},
#   'warnings': []},
#  'cd3+': {'population_name': 'cd3+',
#   'index': array([    301,     329,     636, ..., 1004641, 1004728, 1004799]),
#   'prop_of_parent': 0.7262787482719618,
#   'prop_of_total': 0.005750603519819133,
#   'parent': 'live',
#   'children': ['gdt', 'non_gdt'],
#   'geom': {'threshold': 0.32612715169960066,
#    'method': 'Local minima; two highest peaks',
#    'shape': 'threshold',
#    'x': 'CD3',
#    'y': None},
#   'warnings': []},
#  'cd3-': {'population_name': 'cd3-',
#   'index': array([    141,     910,    1259, ..., 1004194, 1004335, 1004639]),
#   'prop_of_parent': 0.2737212517280382,
#   'prop_of_total': 0.002167297883053482,
#   'parent': 'live',
#   'children': [],
#   'geom': {'threshold': 0.32612715169960066,
#    'method': 'Local minima; two highest peaks',
#    'shape': 'threshold',
#    'x': 'CD3',
#    'y': None},
#   'warnings': []},
#  'gdt': {'population_name': 'gdt',
#   'index': array([    301,   16007,   63645,   63964,   82023,   96782,   99733,
#           113862,  121815,  148944,  153304,  177709,  178921,  202525,
#           203518,  257882,  273062,  292434,  328830,  335511,  365092,
#           382178,  388102,  394527,  399719,  423933,  435478,  435491,
#           440933,  450035,  453168,  468101,  499076,  535455,  537289,
#           552600,  554854,  560776,  577509,  578785,  602652,  606009,
#           656647,  699593,  725945,  743597,  749414,  765824,  766654,
#           767925,  768412,  769970,  779935,  789134,  799843,  810278,
#           840827,  842678,  843277,  843461,  870442,  871976,  875053,
#           897201,  937550,  939183,  946235, 1003142]),
#   'prop_of_parent': 0.011766741650804638,
#   'prop_of_total': 6.766586595391954e-05,
#   'parent': 'cd3+',
#   'children': [],
#   'geom': {'shape': 'cluster', 'x': 'Vd2', 'y': 'PanGD'},
#   'warnings': ['Expected 2 populations, identified 7; {0, 1, 2, 3, 4, 5, 6, -1}']},
#  'non_gdt': {'population_name': 'non_gdt',
#   'index': array([    329,     636,     737, ..., 1004641, 1004728, 1004799]),
#   'prop_of_parent': 0.9813116456134279,
#   'prop_of_total': 0.005643134203304085,
#   'parent': 'cd3+',
#   'children': ['classic_tcells'],
#   'geom': {'shape': 'cluster', 'x': 'Vd2', 'y': 'PanGD'},
#   'warnings': ['Expected 2 populations, identified 7; {0, 1, 2, 3, 4, 5, 6, -1}']},
#  'classic_tcells': {'population_name': 'classic_tcells',
#   'index': array([    329,     636,     737, ..., 1004641, 1004728, 1004799]),
#   'prop_of_parent': 0.9955916064186211,
#   'prop_of_total': 0.005618257046703379,
#   'parent': 'non_gdt',
#   'children': ['cd4', 'cd8'],
#   'geom': {'shape': 'cluster', 'x': 'Va7.2', 'y': 'CD161'},
#   'warnings': ['Expected 2 populations, identified 5; {0, 1, 2, 3, 4, -1}',
#    "Populations f['mait', 'classic_tcells'] assigned to the same cluster 0; prioritising classic_tcells on weighting."]},
#  'cd4': {'population_name': 'cd4',
#   'index': array([    329,     636,     737, ..., 1004641, 1004728, 1004799]),
#   'prop_of_parent': 0.9241941197307828,
#   'prop_of_total': 0.0051923601256992965,
#   'parent': 'classic_tcells',
#   'children': [],
#   'geom': {'shape': 'cluster', 'x': 'CD4', 'y': 'CD8'},
#   'warnings': []},
#  'cd8': {'population_name': 'cd8',
#   'index': array([   2985,    3432,    5816,   15770,   23368,   31447,   33414,
#            36398,   43507,   47001,   48885,   53751,   54679,   55433,
#            56529,   72877,   80448,   85270,   95197,   97820,   99377,
#            99948,  105502,  117366,  120098,  120980,  124285,  134163,
#           134530,  140371,  141504,  154328,  155254,  161357,  163920,
#           169778,  170705,  175120,  176845,  178694,  178950,  183701,
#           183793,  185308,  189583,  189889,  192493,  196645,  201060,
#           206337,  209803,  210236,  216348,  221358,  222821,  224670,
#           226861,  227776,  229820,  237973,  239221,  240698,  241011,
#           241767,  241782,  242627,  248793,  250970,  252040,  258456,
#           262985,  264602,  269553,  277420,  293483,  298539,  300313,
#           305977,  308596,  311664,  314242,  318235,  326585,  331850,
#           334623,  340367,  343155,  343755,  344844,  348799,  350059,
#           351956,  352612,  353024,  354477,  355711,  359614,  369837,
#           371564,  373963,  378598,  382273,  387087,  389704,  396712,
#           397392,  397636,  399267,  400047,  401665,  407191,  410867,
#           412435,  413842,  416794,  419189,  422366,  424758,  427237,
#           427576,  428459,  429170,  433372,  434259,  437048,  439664,
#           440054,  443999,  445573,  448052,  451818,  452234,  452817,
#           452865,  453008,  454652,  456900,  457209,  461095,  464087,
#           464623,  466166,  469365,  472266,  474028,  481325,  483623,
#           487623,  488005,  501635,  502029,  505594,  505860,  506078,
#           508320,  509319,  510007,  512138,  517962,  518900,  519717,
#           520218,  520907,  523592,  525741,  529384,  539230,  539451,
#           542223,  546237,  547331,  547468,  548786,  552369,  555272,
#           555749,  557787,  559292,  564338,  565637,  568699,  577175,
#           579867,  580442,  585608,  586097,  587619,  594545,  599604,
#           602109,  602622,  605210,  606189,  612615,  616329,  618504,
#           625014,  626118,  628917,  630795,  633106,  634728,  635697,
#           638066,  644869,  651161,  655790,  657636,  658525,  660320,
#           675396,  678697,  681499,  683860,  684154,  684872,  685606,
#           686929,  687260,  693343,  698093,  706639,  707541,  708234,
#           712039,  712542,  713447,  719786,  720108,  720959,  721812,
#           722303,  724638,  730522,  736189,  737042,  744974,  751918,
#           757806,  759662,  759934,  760423,  761931,  762293,  770805,
#           772573,  773351,  774786,  780310,  781648,  783001,  783218,
#           783250,  784578,  786490,  788287,  793020,  794501,  795292,
#           801718,  802733,  803270,  804214,  804748,  808811,  809400,
#           809982,  810618,  815751,  818867,  819863,  821894,  823246,
#           824770,  827870,  830947,  837965,  843219,  843275,  843696,
#           844088,  844353,  845310,  850197,  851096,  851221,  854902,
#           858726,  859087,  859830,  867146,  868179,  874382,  876216,
#           877376,  884924,  886492,  888358,  891384,  894309,  900771,
#           902871,  905619,  908447,  909054,  910828,  915832,  916401,
#           917140,  922468,  924251,  925054,  925435,  929082,  936361,
#           938971,  940772,  943955,  947122,  949466,  949868,  950796,
#           953193,  961266,  963674,  963874,  966501,  971056,  974126,
#           974316,  974525,  976035,  979975,  981407,  983762,  983822,
#           985097,  986300,  989329,  991178, 1001310, 1001341]),
#   'prop_of_parent': 0.06057385759829968,
#   'prop_of_total': 0.00034031950229765416,
#   'parent': 'classic_tcells',
#   'children': [],
#   'geom': {'shape': 'cluster', 'x': 'CD4', 'y': 'CD8'},
#   'warnings': []}}

# %%
t_template.save()
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-70-cdf356a0799a> in <module>
# ----> 1 t_template.save()
#
# ~/immunova/immunova/flow/gating/actions.py in save(self, overwrite)
#     510             fg.save()
#     511         for name in self.populations.keys():
# --> 512             FileGroup.objects(primary_id=self.id).update(push__populations=self.__population_to_mongo(name))
#     513         for _, gate in self.gates.items():
#     514             FileGroup.objects(primary_id=self.id).update(push__gates=gate)
#
# ~/immunova/env/lib/python3.7/site-packages/mongoengine/queryset/base.py in update(self, upsert, multi, write_concern, full_result, **update)
#     529                 if multi:
#     530                     update_func = collection.update_many
# --> 531                 result = update_func(query, update, upsert=upsert)
#     532             if full_result:
#     533                 return result
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/collection.py in update_many(self, filter, update, upsert, array_filters, bypass_document_validation, collation, session)
#    1074                 bypass_doc_val=bypass_document_validation,
#    1075                 collation=collation, array_filters=array_filters,
# -> 1076                 session=session),
#    1077             write_concern.acknowledged)
#    1078
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/collection.py in _update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session)
#     854         return self.__database.client._retryable_write(
#     855             (write_concern or self.write_concern).acknowledged and not multi,
# --> 856             _update, session)
#     857
#     858     def replace_one(self, filter, replacement, upsert=False,
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1490         """Internal retryable write helper."""
#    1491         with self._tmp_session(session) as s:
# -> 1492             return self._retry_with_session(retryable, func, s, None)
#    1493
#    1494     def _reset_server(self, address):
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1383                             raise last_error
#    1384                         retryable = False
# -> 1385                     return func(session, sock_info, retryable)
#    1386             except ServerSelectionTimeoutError:
#    1387                 if is_retrying():
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/collection.py in _update(session, sock_info, retryable_write)
#     850                 bypass_doc_val=bypass_doc_val, collation=collation,
#     851                 array_filters=array_filters, session=session,
# --> 852                 retryable_write=retryable_write)
#     853
#     854         return self.__database.client._retryable_write(
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/collection.py in _update(self, sock_info, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session, retryable_write)
#     820             session=session,
#     821             client=self.__database.client,
# --> 822             retryable_write=retryable_write).copy()
#     823         _check_write_command_response(result)
#     824         # Add the updatedExisting field for compatibility.
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     616         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     617         except BaseException as error:
# --> 618             self._raise_connection_failure(error)
#     619
#     620     def send_message(self, message, max_doc_size):
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     611                            use_op_msg=self.op_msg_enabled,
#     612                            unacknowledged=unacknowledged,
# --> 613                            user_fields=user_fields)
#     614         except OperationFailure:
#     615             raise
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields)
#     127         request_id, msg, size, max_doc_size = message._op_msg(
#     128             flags, spec, dbname, read_preference, slave_ok, check_keys,
# --> 129             codec_options, ctx=compression_ctx)
#     130         # If this is an unacknowledged write then make sure the encoded doc(s)
#     131         # are small enough, otherwise rely on the server to return an error.
#
# ~/immunova/env/lib/python3.7/site-packages/pymongo/message.py in _op_msg(flags, command, dbname, read_preference, slave_ok, check_keys, opts, ctx)
#     702                 flags, command, identifier, docs, check_keys, opts, ctx)
#     703         return _op_msg_uncompressed(
# --> 704             flags, command, identifier, docs, check_keys, opts)
#     705     finally:
#     706         # Add the field back to the command.
#
# InvalidDocument: cannot encode object: 73420.78, of type: <class 'numpy.float32'>

# %%
#data = t_template.data.copy()
#data.to_csv('experiment_data/data/pd318_10.csv')

# %%
t_template.fmo['pd318-01_t_CXCR3'].to_csv('experiment_data/data/pd318_10_CXCR3.csv')

# %%
import pickle
with open('experiment_data/data/pd318_10_pops.pickle', 'wb') as f:
    pickle.dump(t_template.populations, f)

# %% [markdown]
# <h2>Iterative KNN gating</h2>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate
from datetime import datetime
import pickle
import numpy as np

# %%
x = pd.DataFrame(np.random.rand(100000, 2), columns=['a', 'b'])

# %%
mask = x[x.a > 0.4].index.values

# %%
# %timeit x.iloc[mask]
# Out:
# 1.17 ms ± 80 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit x[x.index.isin(mask)]
# Out:
# 4.39 ms ± 11.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
data = pd.read_csv('experiment_data/data/pd318_10.csv')
fmo_data = pd.read_csv('experiment_data/data/pd318_10_CXCR3.csv')
with open('experiment_data/data/pd318_10_pops.pickle', 'rb') as f:
    populations = pickle.load(f)

# %% [markdown]
# <h3>Calculate optimal parameters</h3>

# %%
features = ['FSC-A', 'FSC-H', 'FSC-W', 'SSC-A', 'SSC-H', 'SSC-W',
            'CXCR3', 'CD161', 'CD3', 'CCR7', 'L/D', 'Va7.2', 'CD8', 'Vd2', 'CD45RA',
            'PanGD', 'CD4', 'CD27']

# %%
def get_tree(pop_name, route):
    if pop_name != 'root':
        route.append(pop_name)
        return get_tree(populations[pop_name]['parent'], route)
    return route
def knn_find_population(pop_name, fmo_data):
    tree = get_tree(pop_name, [])[::-1]
    fmo_data = fmo_data.copy()
    data_cache = None
    for p in tree:
        parent = populations[p]['parent']
        if data_cache is not None:
            X = data_cache.loc[populations[parent]['index']].copy()
        else:
            X = data.loc[populations[parent]['index']].copy()
        data_cache = X
        x = populations[p]['geom']['x']
        y = populations[p]['geom']['y']
        if not y:
            y = 'FSC-A'
        pos_idx = populations[p]['index']
        X['pos'] = 0
        X.pos = X.pos.mask(X.index.isin(pos_idx), 1)
        Y = X['pos']
        X = X[[x, y]]
        knn = KNeighborsClassifier(n_jobs=-1, algorithm='kd_tree')
        knn.fit(X, Y)
        y_hat = knn.predict(fmo_data[[x, y]])
        fmo_data['pos'] = y_hat
        fmo_data = fmo_data[fmo_data.pos == 1]
    return fmo_data

# %%
# %%timeit -n 1 -r 1
x = knn_find_population('mait', fmo_data)
# Out:
# 5min 28s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# Add fmo index caching and plot the results

# %%
fmo = {'CXCR3' : {'data': fmo_data, 'index_cache': dict()}}

# %%
def population_tree(pop_name, route):
    if pop_name != 'root':
        route.append(pop_name)
        return get_tree(populations[pop_name]['parent'], route)
    return route
def knn_fmo(pop_name, fmo_name):
    # Population has previously been identified for this FMO
    if pop_name in fmo[fmo_name]['index_cache'].keys():
        d = fmo[fmo_name]['data']
        mask = fmo[fmo_name]['index_cache'][pop_name]
        return d.loc[mask]
    # Get population tree
    tree = population_tree(pop_name, [])[::-1]
    # Search FMO cache for existing FMO populations
    start = 0
    for i, p in enumerate(tree):
        if p in fmo[fmo_name]['index_cache'].keys():
            start = i
    if start > 0:
        fmo_data = fmo[fmo_name]['data'].loc[fmo[fmo_name]['index_cache'][tree[start]]].copy()
    else:
        fmo_data = fmo[fmo_name]['data'].copy()
    data_cache = None
    # Iterate over tree and calculate FMO populations
    for p in tree[start:]:
        parent = populations[p]['parent']
        if data_cache is not None:
            X = data_cache.loc[populations[parent]['index']]
        else:
            X = data.loc[populations[parent]['index']].copy()
        data_cache = X
        x = populations[p]['geom']['x']
        y = populations[p]['geom']['y']
        if not y:
            y = 'FSC-A'
        pos_idx = populations[p]['index']
        X['pos'] = 0
        X.pos = X.pos.mask(X.index.isin(pos_idx), 1)
        Y = X['pos']
        X = X[[x, y]]
        knn = KNeighborsClassifier(n_jobs=-1, algorithm='kd_tree')
        knn.fit(X, Y)
        y_hat = knn.predict(fmo_data[[x, y]])
        fmo_data['pos'] = y_hat
        fmo_data = fmo_data[fmo_data.pos == 1]
        fmo[fmo_name]['index_cache'][p] = fmo_data.index.values
    return fmo_data

# %%
# %%timeit -n 1 -r 1
x = knn_fmo('gdt', 'CXCR3')
# Out:
# 6min 6s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %%timeit -n 1 -r 1
x = knn_fmo('mait', 'CXCR3')
# Out:
# 1.86 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %%timeit -n 1 -r 1
x = knn_fmo('mait', 'CXCR3')
# Out:
# 1.58 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
